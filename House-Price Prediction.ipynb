# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("DS - Assignment Part 1 data set.xlsx")

# %%
df.head()
# Out:
#    Transaction date  House Age  Distance from nearest Metro station (km)  \
# 0       2012.916667       32.0                                  84.87882
# 1       2012.916667       19.5                                 306.59470
# 2       2013.583333       13.3                                 561.98450
# 3       2013.500000       13.3                                 561.98450
# 4       2012.833333        5.0                                 390.56840
#
#    Number of convenience stores  latitude  longitude  Number of bedrooms  \
# 0                            10  24.98298  121.54024                   1
# 1                             9  24.98034  121.53951                   2
# 2                             5  24.98746  121.54391                   3
# 3                             5  24.98746  121.54391                   2
# 4                             5  24.97937  121.54245                   1
#
#    House size (sqft)  House price of unit area
# ...

# %%
df.columns
# Out:
# Index(['Transaction date', 'House Age',
#        'Distance from nearest Metro station (km)',
#        'Number of convenience stores', 'latitude', 'longitude',
#        'Number of bedrooms', 'House size (sqft)', 'House price of unit area'],
#       dtype='object')

# %%
df.drop('Transaction date',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   House Age                                 414 non-null    float64
#  1   Distance from nearest Metro station (km)  414 non-null    float64
#  2   Number of convenience stores              414 non-null    int64
#  3   latitude                                  414 non-null    float64
#  4   longitude                                 414 non-null    float64
#  5   Number of bedrooms                        414 non-null    int64
#  6   House size (sqft)                         414 non-null    int64
#  7   House price of unit area                  414 non-null    float64
# dtypes: float64(5), int64(3)
# memory usage: 26.0 KB

# %%
df.describe().T
# Out:
#                                           count         mean          std  \
# House Age                                 414.0    17.712560    11.392485
# Distance from nearest Metro station (km)  414.0  1083.885689  1262.109595
# Number of convenience stores              414.0     4.094203     2.945562
# latitude                                  414.0    24.969030     0.012410
# longitude                                 414.0   121.533361     0.015347
# Number of bedrooms                        414.0     1.987923     0.818875
# House size (sqft)                         414.0   931.475845   348.910269
# House price of unit area                  414.0    37.980193    13.606488
#
#                                                 min         25%        50%  \
# House Age                                   0.00000    9.025000   16.10000
# Distance from nearest Metro station (km)   23.38284  289.324800  492.23130
# Number of convenience stores                0.00000    1.000000    4.00000
# ...

# %%
df.drop(['latitude','longitude'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['House Age', 'Distance from nearest Metro station (km)',
#        'Number of convenience stores', 'Number of bedrooms',
#        'House size (sqft)', 'House price of unit area'],
#       dtype='object')

# %%
plt.figure(figsize=(15,8))

plt.subplot(2,3,1)
sns.distplot(df['House Age'])
plt.subplot(2,3,2)
sns.distplot(df['Distance from nearest Metro station (km)'])
plt.subplot(2,3,3)
sns.distplot(df['Number of convenience stores'])
plt.subplot(2,3,4)
sns.distplot(df['Number of bedrooms'])
plt.subplot(2,3,5)
sns.distplot(df['House size (sqft)'])
plt.subplot(2,3,6)
sns.distplot(df['House price of unit area'])

plt.show()

# %%
plt.figure(figsize=(15,8))

plt.subplot(2,3,1)
sns.boxplot(df['House Age'])
plt.subplot(2,3,2)
sns.boxplot(df['Distance from nearest Metro station (km)'])
plt.subplot(2,3,3)
sns.boxplot(df['Number of convenience stores'])
plt.subplot(2,3,4)
sns.boxplot(df['Number of bedrooms'])
plt.subplot(2,3,5)
sns.boxplot(df['House size (sqft)'])
plt.subplot(2,3,6)
sns.boxplot(df['House price of unit area'])

plt.show()

# %%
plt.figure(figsize=(15,8))

plt.subplot(2,3,1)
sns.scatterplot(df['House price of unit area'],df['House Age'])
plt.subplot(2,3,2)
sns.scatterplot(df['House price of unit area'],df['Distance from nearest Metro station (km)'])
plt.subplot(2,3,3)
sns.scatterplot(df['House price of unit area'],df['Number of convenience stores'])
plt.subplot(2,3,4)
sns.scatterplot(df['House price of unit area'],df['Number of bedrooms'])
plt.subplot(2,3,5)
sns.scatterplot(df['House price of unit area'],df['House size (sqft)'])
plt.subplot(2,3,6)
sns.boxplot(df['House price of unit area'])

plt.show()

# %%
df.head()
# Out:
#    House Age  Distance from nearest Metro station (km)  \
# 0       32.0                                  84.87882
# 1       19.5                                 306.59470
# 2       13.3                                 561.98450
# 3       13.3                                 561.98450
# 4        5.0                                 390.56840
#
#    Number of convenience stores  Number of bedrooms  House size (sqft)  \
# 0                            10                   1                575
# 1                             9                   2               1240
# 2                             5                   3               1060
# 3                             5                   2                875
# 4                             5                   1                491
#
#    House price of unit area
# 0                      37.9
# 1                      42.2
# 2                      47.3
# 3                      54.8
# 4                      43.1

# %%
df.shape
# Out:
# (414, 6)

# %% [markdown]
# Let's make a final Y column i.e output by multiplying House size with price per unit area

# %%
df['Price'] = df['House size (sqft)'] * df['House price of unit area']

# %%
df.drop(['House size (sqft)','House price of unit area'],axis=1,inplace=True)

# %%
sns.boxplot(df['Price'])
# Out:
# <AxesSubplot:xlabel='Price'>

# %% [markdown]
# we can see some outliers so we will remove them
#
# we can also do it by inter-quatile method but i am simply removing them by visualization

# %%
df = df[df['Distance from nearest Metro station (km)'] < 3000]

# %%
sns.boxplot(df['Price'])
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
df = df[df['Price'] < 100000]

# %%
df.shape
# Out:
# (370, 5)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Number of bedrooms and Distance from nearest metro shows strong correlation

# %% [markdown]
# #### Price is directly proportional to Number of Bedrooms

# %% [markdown]
# #### Price is inversly proportional to Distance from nearest metro station

# %%
df.head()
# Out:
#    House Age  Distance from nearest Metro station (km)  \
# 0       32.0                                  84.87882
# 1       19.5                                 306.59470
# 2       13.3                                 561.98450
# 3       13.3                                 561.98450
# 4        5.0                                 390.56840
#
#    Number of convenience stores  Number of bedrooms    Price
# 0                            10                   1  21792.5
# 1                             9                   2  52328.0
# 2                             5                   3  50138.0
# 3                             5                   2  47950.0
# 4                             5                   1  21162.1

# %%
X = df.drop('Price',axis=1)
y = df['Price']

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=0)

# %%
X_train.head()
# Out:
#      House Age  Distance from nearest Metro station (km)  \
# 90         0.0                                 274.01440
# 192       43.8                                  57.58945
# 86         1.8                                1455.79800
# 64        17.5                                 995.75540
# 61         5.3                                 259.66070
#
#      Number of convenience stores  Number of bedrooms
# 90                              1                   2
# 192                             7                   3
# 86                              1                   1
# 64                              0                   2
# 61                              6                   3

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
import xgboost as xg
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
models = {'Linear Regression':LinearRegression(),
          'Decision Tree':DecisionTreeRegressor(),
          'Random Forest':RandomForestRegressor(),
          'XG Boost':xg.XGBRegressor()}


for k,v in models.items():
    print(f"My model is: {k}")
    model = v
    model.fit(X_train,y_train)
    
    
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    #Train
    model_train_mae = mean_absolute_error(y_train,y_train_pred)
    model_train_mse = mean_squared_error(y_train,y_train_pred)
    model_train_rmse = np.sqrt(mean_squared_error(y_train,y_train_pred))
    r2_train = r2_score(y_train,y_train_pred)
    
    #Test
    model_test_mae = mean_absolute_error(y_test,y_test_pred)
    model_test_mse = mean_squared_error(y_test,y_test_pred)
    model_test_rmse = np.sqrt(mean_squared_error(y_test,y_test_pred))
    r2_test = r2_score(y_test,y_test_pred)
    
    
    print(k)
    print('PERFORMANCE OF TRAINING DATA')
    print(f"MAE: {model_train_mae}")
    print(f"MSE: {model_train_mse}")
    print(f"RMSE: {model_train_rmse}")
    print(f"R2_SCORE: {r2_train}")
    
    
    print('------------------------------------------------')
    
    print('PERFORMACE OF TESTING DATA')
    print(f"MAE: {model_test_mae}")
    print(f"MSE: {model_test_mse}")
    print(f"RMSE: {model_test_rmse}")
    print(f"R2_SCORE: {r2_test}")
    
    
    
    print('='*35)
    print()
# Out:
# My model is: Linear Regression
# Linear Regression
# PERFORMANCE OF TRAINING DATA
# MAE: 9082.232423184043
# MSE: 141746326.40441647
# RMSE: 11905.726622277889
# R2_SCORE: 0.5648053424973878
# ------------------------------------------------
# PERFORMACE OF TESTING DATA
# MAE: 6608.674541026112
# MSE: 76369297.71816827
# RMSE: 8738.952895980632
# R2_SCORE: 0.7889032859668182
# ...
#
# My model is: Decision Tree
# Decision Tree
# PERFORMANCE OF TRAINING DATA
# MAE: 338.1713375796178
# MSE: 3944385.1365605085
# RMSE: 1986.0476168915256
# R2_SCORE: 0.9878898072203559
# ------------------------------------------------
# PERFORMACE OF TESTING DATA
# MAE: 7780.664285714286
# MSE: 112805371.89598213
# RMSE: 10620.987331504644
# R2_SCORE: 0.6881882635557119
# ...
#
# My model is: Random Forest
# Random Forest
# PERFORMANCE OF TRAINING DATA
# MAE: 2948.398529830152
# MSE: 18326434.677159254
# RMSE: 4280.938527608082
# R2_SCORE: 0.9437335226606492
# ------------------------------------------------
# ...

# %% [markdown]
# ## Random Forest is the best model according to me

# %% [markdown]
# #### we can also perform Hyper-Parameter Tuning to decrease the error's further more.

# %% [markdown]
# # Thank You!!!
